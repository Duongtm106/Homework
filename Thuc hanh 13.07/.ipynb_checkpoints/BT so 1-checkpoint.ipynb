# %%
#Vẽ 18 hình vuông nội tiếp đường tròn đồng tâm (0,0)
import turtle
t = turtle.Turtle()
canh = 200
#Vẽ hình vuông 1
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 2
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
#Vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(200)
t.left(90)
t.left(18)
turtle.done()
